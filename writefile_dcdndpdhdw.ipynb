# %%
###fileWriter for dc,dn,dp,dh,dw

# %%
### daily output variables

###daily carbon
dc={'START_DATE':'0101','END_DATE':'3112','RESIDUE_C':'YES','HUMUS_C':'YES','AMENDED_C':'YES','LITTER_C':'YES','CO2_FLUX':'YES','O2_FLUX':'YES',
    'AUTO_RESP':'YES','MICRO_C':'YES','SURF_RES':'YES','CH4_FLUX':'YES','SURF_DOC_FLUX':'YES','SUBS_DOC_FLUX':'YES',
    'SURF_DIC_FLUX':'YES','SUBS_DIC_FLUX':'YES','ATM_CO2':'YES','NBP':'YES','FIRE_CO2':'YES','SOC_1':'YES','SOC_2':'YES',
    'SOC_3':'YES','SOC_4':'YES','SOC_5':'YES','SOC_6':'YES','SOC_7':'YES','SOC_8':'YES','SOC_9':'YES','SOC_10':'YES',
    'SOC_11':'YES','SOC_12':'YES','SOC_13':'YES','SOC_14':'YES','SOC_15':'YES','SPACE1':'NO','SPACE2':'NO','SPACE3':'NO',
    'SPACE4':'NO','SPACE5':'NO','SPACE6':'NO','SPACE7':'NO','SPACE8':'NO','H2_FLUX':'YES','ECO_HVST_C':'YES',
    'ECO_LAI':'YES','ECO_GPP':'YES','ECO_RA':'YES','ECO_NPP':'YES','ECO_RH':'YES','FIRE_CH4':'YES','TTL_DIC':'YES',
    'STG_DEAD':'YES','SHOOT_C':'YES','LEAF_C':'YES','SHTH_C':'YES','STALK_C':'YES','RESERVE_C':'YES','REPRO_C':'YES',
    'GRAIN_C':'YES','ROOT_C':'YES','NDL_C':'YES','STORED_C':'YES','GRAIN_NO.':'YES','LAI':'YES','GPP':'YES',
    'EXUD_C':'YES','LITTER_C2':'YES', 'SF_LIT_C':'YES','AUTO_RESP2':'YES','ABV_GRD_RESP':'YES','[SOL_C]':'YES','HVST_C':'YES',
    'DNS_RT_1':'YES','DNS_RT_2':'YES','DNS_RT_3':'YES','DNS_RT_4':'YES','DNS_RT_5':'YES','DNS_RT_6':'YES','DNS_RT_7':'YES','DNS_RT_8':'YES',
    'DNS_RT_9':'YES','DNS_RT_10':'YES','DNS_RT_11':'YES','DNS_RT_12':'YES','DNS_RT_13':'YES','DNS_RT_14':'YES',
    'DNS_RT_15':'YES','C_BALANCE':'YES','STG_DEAD_C':'YES','FIRE_CO22':'YES','FIRE_CH42':'YES','NPP':'YES','CAN_HT':'YES',
    'POPN':'YES','SPACE1e':'NO','SPACE2e':'NO','SPACE3e':'NO','SPACE4e':'NO','SPACE5e':'NO','SPACE6e':'NO','SPACE7e':'NO','SPACE8e':'NO'}
##SPACE# in dc.item refers to the space of binary gap in ecosys

###daily nitrogen
dn={'START_DATE':'0101','END_DATE':'3112','RESIDUE_N':'YES','HUMUS_N':'YES','FERTZR_N':'YES','NET_PL_EXCH_N':'YES','NH4':'YES','NO3':'YES',
    'SURF_DON_FLUX':'YES','SUBS_DON_FLUX':'YES','SURF_DIN_FLUX':'YES','SUBS_DIN_FLUX':'YES','N2O_FLUX':'YES',
    'NH3_FLUX':'YES','N2_FIXN':'YES','MICRO_N':'YES','NH4_1':'YES','NH4_2':'YES','NH4_3':'YES','NH4_4':'YES','NH4_5':'YES',
    'NH4_6':'YES','NH4_7':'YES','NH4_8':'YES','NH4_9':'YES','NH4_10':'YES','NH4_11':'YES','NH4_12':'YES','NH4_13':'YES',
    'NH4_14':'YES','NH4_15':'YES','NO3_1':'YES','NO3_2':'YES','NO3_3':'YES','NO3_4':'YES','NO3_5':'YES',
    'NO3_6':'YES','NO3_7':'YES','NO3_8':'YES','NO3_9':'YES','NO3_10':'YES','NO3_11':'YES','NO3_12':'YES',
    'NO3_13':'YES','NO3_14':'YES','NO3_15':'YES','NH4_RES':'YES','NO3_RES':'YES','ECO_HVST_N':'YES','SPACE1':'NO',
    'FIRE_N':'YES','N2_FLUX':'YES','SHOOT_N':'YES','LEAF_N':'YES','SHTH_N':'YES','STALK_N.':'YES','RESERVE_N':'YES','HUSK_N':'YES',
    'GRAIN_N':'YES','ROOT_N':'YES','NDL_N':'YES','STORED_N':'YES','UPTK_N':'YES','LITTER_N':'YES','TL_N_FIXED':'YES',
    '[SOL_N]':'YES','N_STRESS':'YES','[SOL_P]':'YES','P_STRESS':'YES','NH3_FLUX2':'YES','HVST_N':'YES','N_BALANCE':'YES',
    'STG_DEAD_N':'YES','FIRE_N2':'YES','SF_LIT_N':'YES','SPACE1e':'NO','SPACE2e':'NO','SPACE3e':'NO','SPACE4e':'NO','SPACE5e':'NO',
    'SPACE6e':'NO','SPACE7e':'NO','SPACE8e':'NO','SPACE9e':'NO','SPACE10e':'NO','SPACE11e':'NO','SPACE12e':'NO','SPACE13e':'NO',
    'SPACE14e':'NO','SPACE15e':'NO','SPACE16e':'NO','SPACE17e':'NO','SPACE18e':'NO','SPACE19e':'NO','SPACE20e':'NO','SPACE21e':'NO',
    'SPACE22e':'NO','SPACE23e':'NO','SPACE24e':'NO','SPACE25e':'NO','SPACE26e':'NO','SPACE27e':'NO'}

###daily phosphorus
dp={'START_DATE':'0101','END_DATE':'3112','RESIDUE_P':'YES','HUMUS_P':'YES','FERTZR_P':'YES','NET_PL_EXCH_P':'YES','EXCH_PO4':'YES','SURF_DOP_FLUX':'YES',
    'SUBS_DOP_FLUX':'YES','SURF_DIP_FLUX':'YES','SUBS_DIP_FLUX':'YES','PRECIP_P':'YES','MICRO_P':'YES','FIRE_P':'YES',
    'PO4_1':'YES','PO4_2':'YES','PO4_3':'YES','PO4_4':'YES','PO4_5':'YES','PO4_6':'YES','PO4_7':'YES',
    'PO4_8':'YES','PO4_9':'YES','PO4_10':'YES','PO4_11':'YES','PO4_12':'YES','PO4_13':'YES','PO4_14':'YES','PO4_15':'YES',
    'EXCH_P_1':'YES','EXCH_P_2':'YES','EXCH_P_3':'YES','EXCH_P_4':'YES','EXCH_P_5':'YES','EXCH_P_6':'YES','EXCH_P_7':'YES',
    'EXCH_P_8':'YES','EXCH_P_9':'YES','EXCH_P_10':'YES','EXCH_P_11':'YES','EXCH_P_12':'YES','EXCH_P_13':'YES',
    'EXCH_P_14':'YES','EXCH_P_15':'YES','PO4_RES':'YES','EXCH_P_RES':'YES','SPACE1':'NO','SPACE2':'NO',    
    'ECO_HVST_P':'YES','SPACE3':'NO','SPACE4':'NO','SPACE5':'NO','SHOOT_P':'YES','LEAF_P':'YES',
    'SHTH_P':'YES','STALK_P':'YES','RESERVE_P':'YES','HUSK_P':'YES','GRAIN_P':'YES','ROOT_P':'YES','NDL_P':'YES',
    'STORED_P':'YES','UPTK_P':'YES','LITTER_P':'YES','[SOL_P]':'YES','P_STRESS':'YES','HVST_P':'YES',
    'P_BALANCE':'YES','STG_DEAD_P':'YES','FIRE_P2':'YES','SF_LIT_P':'YES','SPACE1e':'NO','SPACE2e':'NO','SPACE3e':'NO',
    'SPACE4e':'NO','SPACE5e':'NO','SPACE6e':'NO','SPACE7e':'NO','SPACE8e':'NO','SPACE9e':'NO','SPACE10e':'NO','SPACE11e':'NO',
    'SPACE12e':'NO','SPACE13e':'NO','SPACE14e':'NO','SPACE15e':'NO','SPACE16e':'NO','SPACE17e':'NO','SPACE18e':'NO',
    'SPACE19e':'NO','SPACE20e':'NO','SPACE21e':'NO','SPACE22e':'NO','SPACE23e':'NO','SPACE24e':'NO','SPACE25e':'NO',
    'SPACE26e':'NO','SPACE27e':'NO','SPACE28e':'NO','SPACE29e':'NO','SPACE30e':'NO','SPACE31e':'NO'}

###daily heat
dh={'START_DATE':'0101','END_DATE':'3112','RADN':'YES','TMAX_AIR':'YES','TMIN_AIR':'YES','HMAX_AIR':'YES','HMIN_AIR':'YES','WIND':'YES',
    'PRECN':'YES','TMAX_SOIL_1':'YES','TMIN_SOIL_1':'YES','TMAX_SOIL_2':'YES','TMIN_SOIL_2':'YES','TMAX_SOIL_3':'YES',
    'TMIN_SOIL_3':'YES','TMAX_SOIL_4':'YES','TMIN_SOIL_4':'YES','TMAX_SOIL_5':'YES','TMIN_SOIL_5':'YES','TMAX_SOIL_6':'YES',
    'TMIN_SOIL_6':'YES','TMAX_SOIL_7':'YES','TMIN_SOIL_7':'YES','TMAX_SOIL_8':'YES','TMIN_SOIL_8':'YES','TMAX_SOIL_9':'YES',
    'TMIN_SOIL_9':'YES','TMAX_SOIL_10':'YES','TMIN_SOIL_10':'YES','TMAX_SOIL_11':'YES','TMIN_SOIL_11':'YES',
    'TMAX_SOIL_12':'YES','TMIN_SOIL_12':'YES','TMAX_SOIL_13':'YES','TMIN_SOIL_13':'YES','TMAX_SOIL_14':'YES',
    'TMIN_SOIL_14':'YES','TMAX_LITTER':'YES','TMIN_LITTER':'YES','ECND_1':'YES','ECND_2':'YES','ECND_3':'YES','ECND_4':'YES',
    'ECND_5':'YES','ECND_6':'YES','ECND_7':'YES','ECND_8':'YES','ECND_9':'YES','ECND_10':'YES','ECND_10':'YES',
    'ECND_11':'YES','ECND_12':'YES','TTL_SALT_DISCHG':'YES','GROWTH_STG':'YES','BRANCH_NO.':'YES','NODE_NO.':'YES',
    'RUB_ACTVN':'YES','LEAF_N/C':'YES','LEAF_P/C':'YES','MIN_LWP':'YES','O2_STRESS':'YES','TEMP_STRESS':'YES',
    'SPACE1e':'NO','SPACE2e':'NO','SPACE3e':'NO','SPACE4e':'NO','SPACE5e':'NO','SPACE6e':'NO','SPACE7e':'NO',
    'SPACE8e':'NO','SPACE9e':'NO','SPACE10e':'NO','SPACE11e':'NO','SPACE12e':'NO','SPACE13e':'NO','SPACE14e':'NO',
    'SPACE15e':'NO','SPACE16e':'NO','SPACE17e':'NO','SPACE18e':'NO','SPACE19e':'NO','SPACE20e':'NO','SPACE21e':'NO',
    'SPACE22e':'NO','SPACE23e':'NO','SPACE24e':'NO','SPACE25e':'NO','SPACE26e':'NO','SPACE27e':'NO','SPACE28e':'NO',
    'SPACE29e':'NO','SPACE30e':'NO','SPACE31e':'NO','SPACE32e':'NO','SPACE33e':'NO','SPACE34e':'NO','SPACE35e':'NO',
    'SPACE36e':'NO','SPACE37e':'NO','SPACE38e':'NO','SPACE39e':'NO','SPACE40e':'NO','SPACE41e':'NO'}

###daily water
dw={'START_DATE':'0101','END_DATE':'3112','PRECN':'YES','ET':'YES','RUNOFF':'YES','WATER':'YES','DISCHG':'YES','SNOWPACK':'YES',
    'WTR_1':'YES','WTR_2':'YES','WTR_3':'YES','WTR_4':'YES','WTR_5':'YES','WTR_6':'YES',
    'WTR_7':'YES','WTR_8':'YES','WTR_9':'YES','WTR_10':'YES','WTR_11':'YES','WTR_12':'YES',
    'WTR_13':'YES','SURF_WTR':'YES','ICE_1':'YES','ICE_2':'YES','ICE_3':'YES','ICE_4':'YES',
    'ICE_5':'YES','ICE_6':'YES','ICE_7':'YES','ICE_8':'YES','ICE_9':'YES',
    'ICE_10':'YES','ICE_11':'YES','ICE_12':'YES','ICE_13':'YES','SURF_ICE':'YES',
    'PSI_1':'YES','PSI_2':'YES','PSI_3':'YES','PSI_4':'YES','PSI_5':'YES','PSI_6':'YES','PSI_7':'YES',
    'PSI_8':'YES','PSI_9':'YES','PSI_10':'YES','PSI_11':'YES','SEDIMENT':'YES','PSI_SURF':'YES','SURF_ELEV':'YES',
    'ACTV_LYR':'YES','WTR_TBL':'YES','TRANSPN':'YES','WTR_STRESS':'YES','OXY_STRESS':'YES',
    'SPACE1e':'NO','SPACE2e':'NO','SPACE3e':'NO','SPACE4e':'NO','SPACE5e':'NO','SPACE6e':'NO','SPACE7e':'NO',
    'SPACE8e':'NO','SPACE9e':'NO','SPACE10e':'NO','SPACE11e':'NO','SPACE12e':'NO','SPACE13e':'NO','SPACE14e':'NO',
    'SPACE15e':'NO','SPACE16e':'NO','SPACE17e':'NO','SPACE18e':'NO','SPACE19e':'NO','SPACE20e':'NO','SPACE21e':'NO',
    'SPACE22e':'NO','SPACE23e':'NO','SPACE24e':'NO','SPACE25e':'NO','SPACE26e':'NO','SPACE27e':'NO','SPACE28e':'NO',
    'SPACE29e':'NO','SPACE30e':'NO','SPACE31e':'NO','SPACE32e':'NO','SPACE33e':'NO','SPACE34e':'NO','SPACE35e':'NO',
    'SPACE36e':'NO','SPACE37e':'NO','SPACE38e':'NO','SPACE39e':'NO','SPACE40e':'NO','SPACE41e':'NO','SPACE42e':'NO',
    'SPACE43e':'NO','SPACE44e':'NO','SPACE45e':'NO','SPACE46e':'NO','SPACE47e':'NO'}

# %%
dc['NBP']
# Out:
# 'YES'

# %%
print(len(dc))
print(len(dn))
print(len(dp))
print(len(dh))
print(len(dw))
# Out:
# 102
# 102
# 102
# 102
# 102

# %%
for key, value in dw.items():
    print(key,value)
# Out:
# START_DATE 0101
# END_DATE 3112
# PRECN YES
# ET YES
# RUNOFF YES
# WATER YES
# DISCHG YES
# SNOWPACK YES
# WTR_1 YES
# WTR_2 YES
# WTR_3 YES
# WTR_4 YES
# WTR_5 YES
# WTR_6 YES
# WTR_7 YES
# WTR_8 YES
# WTR_9 YES
# WTR_10 YES
# WTR_11 YES
# WTR_12 YES
# WTR_13 YES
# SURF_WTR YES
# ICE_1 YES
# ICE_2 YES
# ICE_3 YES
# ICE_4 YES
# ICE_5 YES
# ICE_6 YES
# ICE_7 YES
# ICE_8 YES
# ICE_9 YES
# ICE_10 YES
# ICE_11 YES
# ICE_12 YES
# ICE_13 YES
# SURF_ICE YES
# PSI_1 YES
# PSI_2 YES
# PSI_3 YES
# PSI_4 YES
# PSI_5 YES
# PSI_6 YES
# PSI_7 YES
# PSI_8 YES
# PSI_9 YES
# PSI_10 YES
# PSI_11 YES
# SEDIMENT YES
# PSI_SURF YES
# SURF_ELEV YES
# ACTV_LYR YES
# WTR_TBL YES
# TRANSPN YES
# WTR_STRESS YES
# OXY_STRESS YES
# SPACE1e NO
# SPACE2e NO
# SPACE3e NO
# SPACE4e NO
# SPACE5e NO
# SPACE6e NO
# SPACE7e NO
# SPACE8e NO
# SPACE9e NO
# SPACE10e NO
# SPACE11e NO
# SPACE12e NO
# SPACE13e NO
# SPACE14e NO
# SPACE15e NO
# SPACE16e NO
# SPACE17e NO
# SPACE18e NO
# SPACE19e NO
# SPACE20e NO
# SPACE21e NO
# ...

# %%
def script_gen_day(input):     ###input dc,dn,dp,dh,dw
    for key, value in input.items():
        print(value)
    return

# %%
script_gen_day(dc)
# Out:
# 0101
# 3112
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO

# %%
def set_output_list(var_dict,var_input):
    var_copy=var_dict.copy()
    for key in var_input:
        var_copy[key]='YES'    ### or "NO" to enable or disable the variables
    return var_copy

# %%
# Original configuration dictionary TEST
dcc = {
    'START_DATE': '0101',
    'END_DATE': '3112',
    'RESIDUE_C': 'YES',
    'HUMUS_C': 'YES',
    # ... (other configuration variables)
    'FIRE_CO2': 'NO',  # We want to enable this variable
    'FIRE_CH4': 'NO',  # We want to enable this variable
    # ... (other configuration variables)
    'C_BALANCE': 'YES',
    'NPP': 'YES',
    'CAN_HT': 'YES',
    'POPN': 'YES',
    # ...
}

# List of variables to enable
variables_to_enable = ['FIRE_CO2', 'FIRE_CH4']

# Call the set_output_list function to enable the specified variables
modified_config = set_output_list(dcc, variables_to_enable)

# Print the modified configuration
print(modified_config)
# Out:
# {'START_DATE': '0101', 'END_DATE': '3112', 'RESIDUE_C': 'YES', 'HUMUS_C': 'YES', 'FIRE_CO2': 'YES', 'FIRE_CH4': 'YES', 'C_BALANCE': 'YES', 'NPP': 'YES', 'CAN_HT': 'YES', 'POPN': 'YES'}
